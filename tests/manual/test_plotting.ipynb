# %%
from config.config_io import load_config, read_data, read_results
from plots.preferences import plot_preferences
from plots.weights import plot_weights
from plots.pies import  plot_pies
from plots.map import plot_maps
from plots.loo import plot_loo

config = load_config("config_plot.yaml", "config_style.yaml")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       5 from plots.map import plot_maps
#       6 from plots.loo import plot_loo
# ----> 8 config = load_config("config_plot.yaml", "config_style.yaml")
#
# File ~/projects/sBlot/config/config_io.py:820, in load_config(config, style_dir)
#     810 """Load and merge all config files into a single Config object.
#     811
#     812 Args:
#    (...)    817     Config object containing both PlotConfig and StyleConfig.
#     818 """
#     819 import importlib.resources as pkg_resources
# --> 820 from sblot import config as config_package
#     822 experiment = ExperimentConfig.from_config_file(config)
#     824 if style_dir is None:
#
# ModuleNotFoundError: No module named 'sblot'

# %%
data = read_data(config)
all_models = list(read_results(config))

# for model in all_models:
#     if config.experiment.plots.weights:
#         plot_weights(model.results, config)
#     if config.experiment.plots.preferences:
#         plot_preferences(model.results, config)
#     if config.experiment.plots.pies:
#         plot_pies(model.results, data, config)
#     if config.experiment.plots.map:
#         plot_maps(model.results, data, config)

if config.experiment.plots.loo:
    plot_loo(all_models, config)
