# %%
from config.config_io import load_plot_config
from config.config_io import PlotConfig

plot_config, style_config = load_plot_config("config_plot.yaml", "config_style.yaml")

# %%
objects, features, confounders = plot_config.read_data()

for model_name, results in plot_config.read_results():
        if plot_config.plots.weights:
            print("schni")
# Out:
# schni

# %%
objects.names
